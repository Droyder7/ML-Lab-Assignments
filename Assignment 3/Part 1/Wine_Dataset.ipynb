# %% [markdown]
# ## Install hmmlearn

# %%
! pip install hmmlearn
# Out:
# Collecting hmmlearn
#   Downloading hmmlearn-0.2.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (374 kB)
#      |████████████████████████████████| 374 kB 30.8 MB/s
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from hmmlearn) (1.19.5)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from hmmlearn) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.16 in /usr/local/lib/python3.7/dist-packages (from hmmlearn) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.16->hmmlearn) (1.0.1)
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.2.6

# %% [markdown]
# # GaussianHMM classifier

# %% [markdown]
# ## Without Tuning

# %% [markdown]
# ### Train : Test = 70 : 30

# %%
# WINE DATASET
# GaussianHMM(Without Tuning)[70-30 split]


import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,test_size=0.3)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d",cmap='Blues')
plt.show()
# Out:
# Confusion Matrix:
# [[18  0  0]
#  [ 2 20  0]
#  [ 0  0 14]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.90      1.00      0.95        18
#            2       1.00      0.91      0.95        22
#            3       1.00      1.00      1.00        14
#
#     accuracy                           0.96        54
#    macro avg       0.97      0.97      0.97        54
# weighted avg       0.97      0.96      0.96        54
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.9629629629629629

# %% [markdown]
# ### Train : Test = 60 : 40

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']


X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.6,test_size=0.4)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
print(confusion_matrix(y_test, strings))

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, strings)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[22  0  0]
#  [ 0 32  1]
#  [ 0  0 17]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      0.97      0.98        33
#            3       0.94      1.00      0.97        17
#
#     accuracy                           0.99        72
#    macro avg       0.98      0.99      0.99        72
# weighted avg       0.99      0.99      0.99        72
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.9861111111111112

# %% [markdown]
# ### Train : Test = 50 : 50

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']


X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.5)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
print(confusion_matrix(y_test, strings))

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, strings)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[31  0  0]
#  [ 6 26  2]
#  [ 0  0 24]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.84      1.00      0.91        31
#            2       1.00      0.76      0.87        34
#            3       0.92      1.00      0.96        24
#
#     accuracy                           0.91        89
#    macro avg       0.92      0.92      0.91        89
# weighted avg       0.92      0.91      0.91        89
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.9101123595505618

# %% [markdown]
# ### Train : Test = 40 : 60

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']


X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.6)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
print(confusion_matrix(y_test, strings))

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, strings)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[35  0  0]
#  [ 8 35  3]
#  [ 0  1 25]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.81      1.00      0.90        35
#            2       0.97      0.76      0.85        46
#            3       0.89      0.96      0.93        26
#
#     accuracy                           0.89       107
#    macro avg       0.89      0.91      0.89       107
# weighted avg       0.90      0.89      0.89       107
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.8878504672897196

# %% [markdown]
# ### Train : Test = 30 : 70

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']


X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.7)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
print(confusion_matrix(y_test, strings))

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, strings)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[34 10  0]
#  [ 0 43  0]
#  [ 0 38  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       1.00      0.77      0.87        44
#            2       0.47      1.00      0.64        43
#            3       0.00      0.00      0.00        38
#
#     accuracy                           0.62       125
#    macro avg       0.49      0.59      0.50       125
# weighted avg       0.51      0.62      0.53       125
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.616
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## With Tuning

# %% [markdown]
# ### Train : Test = 70 : 30

# %%
# WINE DATASET
# GaussianHMM(With Tuning)[70-30 split]

import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,test_size=0.3)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[20  0  0]
#  [ 5 15  0]
#  [ 1 13  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.77      1.00      0.87        20
#            2       0.54      0.75      0.63        20
#            3       0.00      0.00      0.00        14
#
#     accuracy                           0.65        54
#    macro avg       0.43      0.58      0.50        54
# weighted avg       0.48      0.65      0.55        54
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.6481481481481481
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 60 : 40

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[22  0  0]
#  [ 5 26  0]
#  [ 0 19  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.81      1.00      0.90        22
#            2       0.58      0.84      0.68        31
#            3       0.00      0.00      0.00        19
#
#     accuracy                           0.67        72
#    macro avg       0.46      0.61      0.53        72
# weighted avg       0.50      0.67      0.57        72
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 50 : 50

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[25  0  0]
#  [10 27  0]
#  [ 0 27  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.71      1.00      0.83        25
#            2       0.50      0.73      0.59        37
#            3       0.00      0.00      0.00        27
#
#     accuracy                           0.58        89
#    macro avg       0.40      0.58      0.48        89
# weighted avg       0.41      0.58      0.48        89
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.5842696629213483
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 40 : 60

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.6)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[ 0 37  0]
#  [ 2 43  0]
#  [25  0  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        37
#            2       0.54      0.96      0.69        45
#            3       0.00      0.00      0.00        25
#
#     accuracy                           0.40       107
#    macro avg       0.18      0.32      0.23       107
# weighted avg       0.23      0.40      0.29       107
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.40186915887850466
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 30 : 70

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.7)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GaussianHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[39  0  0]
#  [47  7  0]
#  [ 1 31  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.45      1.00      0.62        39
#            2       0.18      0.13      0.15        54
#            3       0.00      0.00      0.00        32
#
#     accuracy                           0.37       125
#    macro avg       0.21      0.38      0.26       125
# weighted avg       0.22      0.37      0.26       125
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.368
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # GMMHMM classifier

# %% [markdown]
# ## Without Tuning

# %% [markdown]
# ### Train : Test = 70 : 30

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,test_size=0.3)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d",cmap='Blues')
plt.show()
# Out:
# Confusion Matrix:
# [[14  1  0]
#  [ 2 19  1]
#  [ 0  0 17]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.88      0.93      0.90        15
#            2       0.95      0.86      0.90        22
#            3       0.94      1.00      0.97        17
#
#     accuracy                           0.93        54
#    macro avg       0.92      0.93      0.93        54
# weighted avg       0.93      0.93      0.93        54
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.9259259259259259

# %% [markdown]
# ### Train : Test = 60 : 40

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']


X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.6,test_size=0.4)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
print(confusion_matrix(y_test, strings))

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, strings)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[22  0  1]
#  [ 0  0 28]
#  [ 0 20  1]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       1.00      0.96      0.98        23
#            2       0.00      0.00      0.00        28
#            3       0.03      0.05      0.04        21
#
#     accuracy                           0.32        72
#    macro avg       0.34      0.33      0.34        72
# weighted avg       0.33      0.32      0.32        72
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.3194444444444444

# %% [markdown]
# ### Train : Test = 50 : 50

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']


X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.5)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
print(confusion_matrix(y_test, strings))

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, strings)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[32  0  0]
#  [ 0  0 34]
#  [ 0 22  1]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        32
#            2       0.00      0.00      0.00        34
#            3       0.03      0.04      0.03        23
#
#     accuracy                           0.37        89
#    macro avg       0.34      0.35      0.34        89
# weighted avg       0.37      0.37      0.37        89
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.3707865168539326

# %% [markdown]
# ### Train : Test = 40 : 60

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']


X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.6)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
print(confusion_matrix(y_test, strings))

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, strings)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[ 1 31  1]
#  [37  8  3]
#  [ 1  0 25]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.03      0.03      0.03        33
#            2       0.21      0.17      0.18        48
#            3       0.86      0.96      0.91        26
#
#     accuracy                           0.32       107
#    macro avg       0.36      0.39      0.37       107
# weighted avg       0.31      0.32      0.31       107
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.3177570093457944

# %% [markdown]
# ### Train : Test = 30 : 70

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']


X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.7)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=3, covariance_type="full")
classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
print(confusion_matrix(y_test, strings))

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, strings)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[40  1  0]
#  [14 34  0]
#  [24 10  2]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.51      0.98      0.67        41
#            2       0.76      0.71      0.73        48
#            3       1.00      0.06      0.11        36
#
#     accuracy                           0.61       125
#    macro avg       0.76      0.58      0.50       125
# weighted avg       0.75      0.61      0.53       125
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.608

# %% [markdown]
# ## With Tuning

# %% [markdown]
# ### Train : Test = 70 : 30

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,test_size=0.3)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[19  0  0]
#  [ 5 16  0]
#  [ 1 13  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.76      1.00      0.86        19
#            2       0.55      0.76      0.64        21
#            3       0.00      0.00      0.00        14
#
#     accuracy                           0.65        54
#    macro avg       0.44      0.59      0.50        54
# weighted avg       0.48      0.65      0.55        54
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.6481481481481481
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 60 : 40

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[18  5  0]
#  [ 0 23  0]
#  [ 0 26  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       1.00      0.78      0.88        23
#            2       0.43      1.00      0.60        23
#            3       0.00      0.00      0.00        26
#
#     accuracy                           0.57        72
#    macro avg       0.48      0.59      0.49        72
# weighted avg       0.46      0.57      0.47        72
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.5694444444444444
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 50 : 50

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[30  0  0]
#  [31  4  0]
#  [ 1 23  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.48      1.00      0.65        30
#            2       0.15      0.11      0.13        35
#            3       0.00      0.00      0.00        24
#
#     accuracy                           0.38        89
#    macro avg       0.21      0.37      0.26        89
# weighted avg       0.22      0.38      0.27        89
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.38202247191011235
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 40 : 60

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.6)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[ 0 31  0]
#  [21 26  0]
#  [29  0  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        31
#            2       0.46      0.55      0.50        47
#            3       0.00      0.00      0.00        29
#
#     accuracy                           0.24       107
#    macro avg       0.15      0.18      0.17       107
# weighted avg       0.20      0.24      0.22       107
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.24299065420560748
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 30 : 70

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.7)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'covariance_type': covariance_type,
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[ 0 45  0]
#  [ 9 39  0]
#  [32  0  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        45
#            2       0.46      0.81      0.59        48
#            3       0.00      0.00      0.00        32
#
#     accuracy                           0.31       125
#    macro avg       0.15      0.27      0.20       125
# weighted avg       0.18      0.31      0.23       125
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.312
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # MultinomialHMM classifier

# %% [markdown]
# ## Without Tuning

# %% [markdown]
# ### Train : Test = 70 : 30

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.MultinomialHMM(n_components=3)


import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
# y = np.absolute(y)
X_test = y

classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:54]


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d",cmap='Blues')
plt.show()
# Out:
# Confusion Matrix:
# [[18  2  0]
#  [15  4  0]
#  [13  2  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.39      0.90      0.55        20
#            2       0.50      0.21      0.30        19
#            3       0.00      0.00      0.00        15
#
#     accuracy                           0.41        54
#    macro avg       0.30      0.37      0.28        54
# weighted avg       0.32      0.41      0.31        54
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.4074074074074074
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 60 : 40

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.MultinomialHMM(n_components=3)


import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
# y = np.absolute(y)
X_test = y

classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[19  5  1]
#  [19  4  0]
#  [20  4  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.33      0.76      0.46        25
#            2       0.31      0.17      0.22        23
#            3       0.00      0.00      0.00        24
#
#     accuracy                           0.32        72
#    macro avg       0.21      0.31      0.23        72
# weighted avg       0.21      0.32      0.23        72
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.3194444444444444

# %% [markdown]
# ### Train : Test = 50 : 50

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.MultinomialHMM(n_components=3)


import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
# y = np.absolute(y)
X_test = y

classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[26  0  6]
#  [28  0  4]
#  [17  0  8]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.37      0.81      0.50        32
#            2       0.00      0.00      0.00        32
#            3       0.44      0.32      0.37        25
#
#     accuracy                           0.38        89
#    macro avg       0.27      0.38      0.29        89
# weighted avg       0.26      0.38      0.29        89
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.38202247191011235
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 40 : 60

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.6)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.MultinomialHMM(n_components=3)


import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_test = y

classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[33  1  5]
#  [36  3  2]
#  [24  0  3]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.35      0.85      0.50        39
#            2       0.75      0.07      0.13        41
#            3       0.30      0.11      0.16        27
#
#     accuracy                           0.36       107
#    macro avg       0.47      0.34      0.27       107
# weighted avg       0.49      0.36      0.27       107
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.3644859813084112

# %% [markdown]
# ### Train : Test = 30 : 70

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.6)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Classification
from hmmlearn import hmm

classifier = hmm.MultinomialHMM(n_components=3)


import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_test = y

classifier.fit(X_train)

y_pred = classifier.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# Confusion Matrix:
# [[ 3 23 11]
#  [ 8 22 12]
#  [ 2 20  6]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.23      0.08      0.12        37
#            2       0.34      0.52      0.41        42
#            3       0.21      0.21      0.21        28
#
#     accuracy                           0.29       107
#    macro avg       0.26      0.27      0.25       107
# weighted avg       0.27      0.29      0.26       107
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.2897196261682243

# %% [markdown]
# ## With Tuning

# %% [markdown]
# ### Train : Test = 70 : 30

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_test = y

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'],
#  'covariance_type': ['spherical', 'tied', 'full', 'diag'],
#  'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[10 13  0]
#  [ 5 13  0]
#  [ 1 12  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.62      0.43      0.51        23
#            2       0.34      0.72      0.46        18
#            3       0.00      0.00      0.00        13
#
#     accuracy                           0.43        54
#    macro avg       0.32      0.39      0.33        54
# weighted avg       0.38      0.43      0.37        54
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.42592592592592593
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 60 : 40

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_test = y

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'], 'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[12  6  0]
#  [11 12  0]
#  [ 9  4  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.38      0.67      0.48        18
#            2       0.55      0.52      0.53        23
#            3       0.00      0.00      0.00        13
#
#     accuracy                           0.44        54
#    macro avg       0.31      0.40      0.34        54
# weighted avg       0.36      0.44      0.39        54
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.4444444444444444
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 50 : 50

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_test = y

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'], 'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[11 19  0]
#  [10 23  0]
#  [ 9 17  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.37      0.37      0.37        30
#            2       0.39      0.70      0.50        33
#            3       0.00      0.00      0.00        26
#
#     accuracy                           0.38        89
#    macro avg       0.25      0.35      0.29        89
# weighted avg       0.27      0.38      0.31        89
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.38202247191011235
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 40 : 60

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.6)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_test = y

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'], 'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[12 27  0]
#  [15 27  0]
#  [12 14  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.31      0.31      0.31        39
#            2       0.40      0.64      0.49        42
#            3       0.00      0.00      0.00        26
#
#     accuracy                           0.36       107
#    macro avg       0.23      0.32      0.27       107
# weighted avg       0.27      0.36      0.30       107
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.3644859813084112
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Train : Test = 30 : 70

# %%
import pandas as pd
import numpy as np

# Dataset Preparation
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids',
            'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

X = df.drop(['Class'], axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.7)


# Feature Scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

n_components = [int(x) for x in np.linspace(1,5, num = 5)]

covariance_type = ['spherical', 'tied', 'full', 'diag']

algorithm = ['viterbi', 'map']

n_iter = [int(x) for x in np.linspace(10, 1000, num = 5)]

# Create the random grid
random_grid = {
               'algorithm': algorithm,
               'n_iter': n_iter}

from pprint import pprint

pprint(random_grid)
print()

# Classification
from hmmlearn import hmm

classifier = hmm.GMMHMM(n_components=2)

from sklearn.model_selection import GridSearchCV
rf_random = GridSearchCV(classifier, random_grid, refit=True)

import math
row = len(X_train)
col = len(X_train[0])
new =  [1] * 13

for i in range(row):
    for j in range(col):
        X_train[i][j] = X_train[i][j]*10
        X_train[i][j] = math.floor(X_train[i][j])
    x = X_train[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_train = y


import math
row = len(X_test)
col = len(X_test[0])
new = [1] * 13

for i in range(row):
    for j in range(col):
        X_test[i][j] = X_test[i][j]*10
        X_test[i][j] = math.floor(X_test[i][j])
    x = X_test[i].astype(np.int)
    new = np.vstack([new,x])

y = new
y = np.absolute(y)
X_test = y

rf_random.fit(X_train)

y_pred = rf_random.predict(X_test)

size = len(y_pred)
strings = np.empty(size, np.unicode_)

for i in range (size):
    if y_pred[i] == 0:
      strings[i] = 1
    elif y_pred[i] == 1:
      strings[i] = 2
    else:
      strings[i] = 3

strings = strings.astype(np.int)
strings = strings[0:y_test.size]

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:")
cm = confusion_matrix(y_test, strings)
print(cm)

print("--------------------------------------------------")
print("--------------------------------------------------")


print("Performance Evaluation")
print(classification_report(y_test, strings))


print("--------------------------------------------------")
print("--------------------------------------------------")

print("Accuracy:")
print(accuracy_score(y_test, strings))

import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
plt.show()
# Out:
# {'algorithm': ['viterbi', 'map'], 'n_iter': [10, 257, 505, 752, 1000]}
#
# Confusion Matrix:
# [[30 16  0]
#  [27 16  0]
#  [26 10  0]]
# --------------------------------------------------
# --------------------------------------------------
# Performance Evaluation
#               precision    recall  f1-score   support
#
#            1       0.36      0.65      0.47        46
#            2       0.38      0.37      0.38        43
#            3       0.00      0.00      0.00        36
#
#     accuracy                           0.37       125
#    macro avg       0.25      0.34      0.28       125
# weighted avg       0.26      0.37      0.30       125
#
# --------------------------------------------------
# --------------------------------------------------
# Accuracy:
# 0.368
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
